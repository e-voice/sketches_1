# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %%
peaks = 1000
t = np.arange(peaks)

# %%
sinus = np.arange(peaks)
sinus = np.sin(sinus)
cosin = np.cos(np.arange(peaks)+0) # увеличить амплитуду
func1 = np.cos(5*t)+np.cos(2*t)
func2 = 1.5*np.cos(5*t)+np.cos(2*t)
func3 = 1.5*np.sin(5*t)+np.sin(2*t)

# %%
#plt.plot(t,func1,'b',t,func2,'r',t,func3,'g')
#plt.show()

# %%
plt.plot(range(peaks),cosin,range(peaks),sinus)
plt.show()

# %%
sp_sin = np.fft.fft(sinus)
sp_cos = np.fft.fft(cosin)
sp_cos1 = np.fft.fft(func3)
freq = np.fft.fftfreq(t.shape[-1])
#plt.plot(freq, sp_sin.real, 'b', freq, sp_sin.imag, 'g',freq, sp_cos.real, 'y', freq, sp_cos.imag, 'black')
plt.plot(freq, sp_sin.imag, 'g', freq, sp_cos.imag, 'black')#,freq, sp_cos1.imag, 'r')
plt.show()

# %%
plt.plot(freq, sp_sin.real, 'b',freq, sp_cos.real, 'y')#,freq, sp_cos1.real, 'g')
plt.show()
